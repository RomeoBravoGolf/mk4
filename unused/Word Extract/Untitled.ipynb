# %%
from PIL import Image
import pytesseract
from wand.image import Image as Img
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import numpy as np
#from tesseract import image_to_string


import cv2
import os
import math

#crear directorio para los frames del video

if not os.path.exists('image_frames'):
    os.makedirs('image_frames')
    
test_vid = cv2.VideoCapture('testvideo.mp4')
frameRate = test_vid.get(5)

index = 0
while test_vid.isOpened():
    ret,frame = test_vid.read()
    frameId = test_vid.get(1)
    if not ret:
        break
        
#asignar un nombre a nuestros archivos:
    name = './image_frames/frame' + str(index) + "." + str(int(frameId)) + '.png'
    
#asignar nuestro print statement
    if (frameId % math.floor(frameRate) == 0):
        print ('Extracting frames...' + name)
        cv2.imwrite(name, frame)
        index = index + 1
        #path = "./image_frames/frame0.png"

        demo = Image.open(name)
        text = pytesseract.image_to_string(demo, lang = 'eng')
        print(text)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break     
            






test_vid.release()
cv2.destroyAllWindows()  #destruir todas las ventanas abiertas
# Out:
# Extracting frames..../image_frames/frame0.29.png
# DICIONARIO
#
# MONIQUE CANTO-SPERBER
#
# DE ETICAE
# FILOSOFIA
#
#
#
# $9NDN.LHO<
# ih
# a
#
# oF hae a) te
#
# DICIONARIO
#
# DE
# ny(@)aulen\
#
# DICIONARIO
# DE
#
# RCO) aw Ler.\
# Extracting frames..../image_frames/frame1.58.png
# DICIONARIO
# DE ETICA E
# FILOSOFIA
#
# MORAL
#
#
#
# S$3NDNLYOc
# NLL"
# (a
#
# oT ONE
#
# TC See ore
#
# DICIONARIO
#
# DE
# BIOETICA
#
# DICIONARIO
#
# vy:
# CO) aul@r\
# Extracting frames..../image_frames/frame2.87.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     497     try:
# --> 498         fh = fp.fileno()
#     499         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-be5dc6b9a4f8> in <module>
#      39
#      40         demo = Image.open(name)
# ---> 41         text = pytesseract.image_to_string(demo, lang = 'eng')
#      42         print(text)
#      43
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type)
#     307         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     308         Output.STRING: lambda: run_and_get_output(*args),
# --> 309     }[output_type]()
#     310
#     311
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/pytesseract/pytesseract.py in <lambda>()
#     306         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     307         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 308         Output.STRING: lambda: run_and_get_output(*args),
#     309     }[output_type]()
#     310
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, return_bytes)
#     206     temp_name, input_filename = '', ''
#     207     try:
# --> 208         temp_name, input_filename = save_image(image)
#     209         kwargs = {
#     210             'input_filename': input_filename,
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/pytesseract/pytesseract.py in save_image(image)
#     134
#     135     input_file_name = temp_name + os.extsep + img_extension
# --> 136     image.save(input_file_name, format=img_extension, **image.info)
#     137     return temp_name, input_file_name
#     138
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2086
#    2087         try:
# -> 2088             save_handler(self, fp, filename)
#    2089         finally:
#    2090             # do what we can to clean up
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     907         chunk(fp, b"eXIf", exif)
#     908
# --> 909     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#     910
#     911     chunk(fp, b"IEND", b"")
#
# /anaconda3/envs/FaceRecon/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     510             else:
#     511                 while True:
# --> 512                     l, s, d = e.encode(bufsize)
#     513                     fp.write(d)
#     514                     if s:
#
# KeyboardInterrupt:
