# %%
from PIL import Image
import pytesseract
from wand.image import Image as Img
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import numpy as np
#from tesseract import image_to_string

from scipy import misc
import imageio
import cv2
import os
import math

#crear directorio para los frames del video
if not os.path.exists('image_frames'):
    os.makedirs('image_frames')
    
test_vid = cv2.VideoCapture('testvideo.mp4')
frameRate = test_vid.get(5)

index = 0
while test_vid.isOpened():
    ret,frame = test_vid.read()
    frameId = test_vid.get(1)
    if not ret:
        break
        
#asignar un nombre a nuestros archivos:
    name = './image_frames/frame' + str(index) + "." + str(int(frameId)) + '.png'
    
#asignar nuestro print statement
    if (frameId % math.floor(frameRate) == 0):
        print ('Extracting frames...' + name)
        cv2.imwrite(name, frame)
        index = index + 1
        #path = "./image_frames/frame0.png"

        demo = Image.open(name)
        

        
        #def long_slice( slice_size):
        """slice an image into parts slice_size tall"""
        #slice_size = 1000
        cuts = 3
        slice_size = height / cuts
        
        img = Image.open(name)
        width, height = img.size
        upper = 0
        left = 0
        slices = int(math.ceil(height/slice_size))
        
        
        
        count = 1
        for slice in range(slices):
            #if we are at the end, set the lower bound to be the bottom of the image
            if count == slices:
                lower = height
            else:
                lower = int(count * slice_size)  

            bbox = (left, upper, width, lower)
            working_slice = img.crop(bbox)
            upper += slice_size
            count +=1
            #save the slice
            if count == 4:
                slice_path = './image_frames/frame' + str(index) + "." + str(int(frameId)) + str(count) + '.png'
                os.remove(file)
                working_slice.save(os.path.join(slice_path))
                text = pytesseract.image_to_string(slice_path)
                print(text)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break     
            


test_vid.release()
cv2.destroyAllWindows()  #destruir todas las ventanas abiertas
# Out:
# Extracting frames..../image_frames/frame0.25.png
#
# Extracting frames..../image_frames/frame1.50.png
#
# Extracting frames..../image_frames/frame2.75.png
#
# Extracting frames..../image_frames/frame3.100.png
#
# Extracting frames..../image_frames/frame4.125.png
# ase")
# Extracting frames..../image_frames/frame5.150.png
#
# Extracting frames..../image_frames/frame6.175.png
#
# Extracting frames..../image_frames/frame7.200.png
# — ELSECR
# Extracting frames..../image_frames/frame8.225.png
# ELSECR
# Extracting frames..../image_frames/frame9.250.png
#
# Extracting frames..../image_frames/frame10.275.png
#
# Extracting frames..../image_frames/frame11.300.png
# a. Vi ab
#
# == QUE SE SABE DELDI
# Extracting frames..../image_frames/frame12.325.png
#
# Extracting frames..../image_frames/frame13.350.png
# - ——
# So aro K Tey, \0\) =  ——
#
# == QUE SE SABE DEL DI
#
#
#
# ¢
# S
#
# —
# Extracting frames..../image_frames/frame14.375.png
# ¢ ——
# SS "ELSECRETO MEJOR GUARDADO — _
#
# == QUE SE SABE DEL DISCURSO DE MA Ec
# Extracting frames..../image_frames/frame15.400.png
# @ _ELSECRETO MEJOR GUARDADO = a
# eee AS 37ey 50 At fs
# Extracting frames..../image_frames/frame16.425.png
# i
#
# C _ELSECRETO MEJOR GUARDADO — a Ce
# === QUE SE SABE DE JRSO nN
# Extracting frames..../image_frames/frame17.450.png
# » >
# SNS 1 acoN so LUV). e) eae ae . ~.
#
# === QUE SE SABE DELD Je AURI Cc
# Extracting frames..../image_frames/frame18.475.png
# A
#
# )
# 4\
# \
# y
#
# == QUE SE SABE DE JRSO DE MAURIC
#
# S __ELSECRETO MEJOR GUARDADO i al
# Extracting frames..../image_frames/frame19.500.png
# y Le
# i
#
# Ss ee. a | ~?——a y f
# == QUE SE SABE DEL DISCURSO DE MA Cc
# Extracting frames..../image_frames/frame20.525.png
#
# Extracting frames..../image_frames/frame21.550.png
#
# Extracting frames..../image_frames/frame22.575.png
# A z
# Ss ELSECRETO MEJOR GUARDADO — ei
#
# SESSA am Sell Sol Lavy =
# Extracting frames..../image_frames/frame23.600.png
# g Fame Lavoe) Ker) = ane f I
# SECA UM Sel ola rye an A
# Extracting frames..../image_frames/frame24.625.png
# a oo lh,
#
# 2 a =
# ELSECRETO MEJORGUARDADO | @ ie = iz
#
# SEAT Ue Sel ola roy Ce an A
# Extracting frames..../image_frames/frame25.650.png
# » | ~~ | a >
# i a |
# SES 1 ose) XG) | Ps .
#
# anol IAIN) ADM ell
# Extracting frames..../image_frames/frame26.675.png
# I¢ - : —— +
# : Eee sey ae fi yY
# Extracting frames..../image_frames/frame27.700.png
# A —————— we)
# Ss [ SECRETO MEJOR biol ee —_— |
# od QUE SE SABE DEL DI ‘ A\U] =
# Extracting frames..../image_frames/frame28.725.png
# Ss : I SECRETO MEJOR Leal a R
# === QUE SE SABE DEL DI ( AUI i:
# Extracting frames..../image_frames/frame29.750.png
# a. os & I~»
# S ELSECRETO MEJOR GUARDADO ah _—
# === QUE SE SABE DEL DISCURSC te
# Extracting frames..../image_frames/frame30.775.png
# ‘ i | Fi 4
# Cl ——— ; _
# Spee sox Gre ivan.)
#
# ap) Myo] eM?) AMVC: Cc
#
#
#
#
# ae TTI
# Extracting frames..../image_frames/frame31.800.png
# ~ ELSECRETO MEJOR GUARDADO
#
# EDEL
#
#
#
#
#
#
# aol ASTIN:
# Extracting frames..../image_frames/frame32.825.png
# € | M 4 al
# Bese aos G Ure en Ki
#
# aol] oP) -AVNG); Cc
#
#
#
#
# ane TTI
# Extracting frames..../image_frames/frame33.850.png
# Lg | \ > =
# — EL SECRETO MEJOR GUARDADO |
#
# SC AIST U TAM Solve
# Extracting frames..../image_frames/frame34.875.png
# V4 } HY a =—
# “S__ELSECRETO MEJOR GUARDADO i ~.
#
# == QUE SE SABE DEL DISCURSC ’
# Extracting frames..../image_frames/frame35.900.png
# Ja ee
#
# S— ELSECRETO MEJOR GUARDADO a Sad
# === QUE SE SABE DEL DISCURSO DE MA i
# Extracting frames..../image_frames/frame36.925.png
# a. ea
#
# S— EL SECRETO MEJOR GUARDADO a Na is
#
# SRC STU Mel oP A ole ol an
# Extracting frames..../image_frames/frame37.950.png
# 4 ~ 7! ~
# eee... = = eS
# ~— ELSECRETO MEJOR GUARDADO a Cae
#
# aeRO ATIC ANAM alo) AVY, Cc
# Extracting frames..../image_frames/frame38.975.png
# ‘See | ! , a
# Cea ae a—— P.. >»
# ~~ ELSECRETO MEJOR GUARDADO ape \
#
# a KON TITIAN AM alo) AVY: Cc
# Extracting frames..../image_frames/frame39.1000.png
# M2 < =
#
# > ELSECRETO MEJOR GUARDADO ee
# Seem USS eeu ODAC
# Extracting frames..../image_frames/frame40.1025.png
# \ Oe a —_—
# SEIS a cel Kay Oe ae és.
# Extracting frames..../image_frames/frame41.1050.png
# ( : a
# ee 3431100 to) Ke) ™ tf, | ee
# Extracting frames..../image_frames/frame42.1075.png
# ( ) s , ae  .
# Bee 411 Kelle), elo wi 4
#
# === QUE SE SABE DELDI
# Extracting frames..../image_frames/frame43.1100.png
# Vl
#
# S if SECRETO MEJORGUARDADO a a
# === QUESE SABE DELD
# Extracting frames..../image_frames/frame44.1125.png
# \ a _ z = a
# > EL SECRETO MEJOR GUARDADO ae
#
# == QUE SE SABE DELDI
# Extracting frames..../image_frames/frame45.1150.png
# \ a ee
# ->— ELSECRETO MEJOR GUARDADO wn
#
# == QUE SE SABE DELDI
# Extracting frames..../image_frames/frame46.1175.png
# C cer
# Ss fas oC eX. ae
#
#
#
#
#
#
# === QUESE SABE DEL DISC ) Y
# Extracting frames..../image_frames/frame47.1200.png
# Va
#
# > — ELSECRETO MEJOR GUARDADO aaa
#
# === QUE SE SABE DEL DISCURSO DE MA
# Extracting frames..../image_frames/frame48.1225.png
# Wi : Ca.
# oa ON ToL TG ee
#
# elt TSAI ANAM a ola VV |
# Extracting frames..../image_frames/frame49.1250.png
# } es i
#
# R310), K. G1) en
#
#
#
#
#
#
# === QUESE SABE DEL DISC y A
# Extracting frames..../image_frames/frame50.1275.png
# Y
#
# / { 2 — : a
# SS ELSECRETO MEJOR GUARDADO wi
#
# Snel] 45 39 4PM ee] eo) yay
# Extracting frames..../image_frames/frame51.1300.png
#
# Extracting frames..../image_frames/frame52.1325.png
# C.. BA 2 see i>
# Extracting frames..../image_frames/frame53.1350.png
# Y
#
# if sa EE
# SS ELSECRETO MEJOR GUARDADO (an
#
# a KOA TIC ANAM al) o) AVY, i
# Extracting frames..../image_frames/frame54.1375.png
# Y
#
# jl es a
# ge et ce): KU Go
#
# EDELD
#
#
#
#
# ae TIC
# Extracting frames..../image_frames/frame55.1400.png
#
# Extracting frames..../image_frames/frame56.1425.png
# V4
#
# we
# S—_ELSECRETO MEJOR GUARDADO
#
# = ae 5
# Extracting frames..../image_frames/frame57.1450.png
# / i
# yy
#
# See IT ny = >,
# eee OSS 7.21) 4 eS ’ 7
# Extracting frames..../image_frames/frame58.1475.png
# V4
#
# ( ~¥§ : - rn
# eee 10171-1130): Ke). Lo ——wo
#
# See T5491 401M at] VNU | ipe
# Extracting frames..../image_frames/frame59.1500.png
# y : J
# Nt 5 —— (
# — ELSECRETO MEJOR GUARDADO ro a.
#
# === QUE SE SABE DEL DISC
# Extracting frames..../image_frames/frame60.1525.png
# YW i era
# S— ELSECRETO MEJOR GUARDADO a
# Extracting frames..../image_frames/frame61.1550.png
# Cre... —s I>,
#
# S— EL SECRETO MEJOR GUARDADO ’ in . Er
#
#
#
# == QUE SE SABE DEL DISCURSC , (C
# Extracting frames..../image_frames/frame62.1575.png
# G
# Y
#
# ( aa i
# > —_ EL SECRETO MEJOR GUARDADO . ae "oi -
# See Sel s0
# Extracting frames..../image_frames/frame63.1600.png
# Y
#
# ( \ ——
# > —_ EL SECRETO MEJOR GUARDADO —_
# === QUE SE SABE DELDI xe ; | i
# Extracting frames..../image_frames/frame64.1625.png
# an:
#
# eet J PA a
# EL SECRETO MEJOR GUARDADO z 7
#
# Eee) 85
# Extracting frames..../image_frames/frame65.1650.png
# i =
# eh Pp iN ——
# EL SECRETO MEJOR GUARDADO ==
#
# eee 0) 85
# Extracting frames..../image_frames/frame66.1675.png
# f
#
# fi} J 1
# I ik Pp. ee 7 BIE -
# EL SECRETO MEJOR GUARDADO
#
# one) ) 3
# Extracting frames..../image_frames/frame67.1700.png
# / D
# EL SECRETO MEJOR GUARDADO
#
# <= QUE
# Extracting frames..../image_frames/frame68.1725.png
# / lf
# (p Oe
#
# U
# EL SECRETO MEJOR GUARDADO.
#
# a QUES
# Extracting frames..../image_frames/frame69.1750.png
# i
# EL SECRETO MEJOR GUARDADO.
#
# QUES
# Extracting frames..../image_frames/frame70.1775.png
# a: ——
#
# it
# EL SECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DI IClO MACRI
# Extracting frames..../image_frames/frame71.1800.png
# G
# EL SECRETO MEJOR GUARDADO co
#
# QUE SE SABE DEL DI
# Extracting frames..../image_frames/frame72.1825.png
# if
# EL SECRETO MEJOR GUARDADO. is
#
# QUE SE SABE DEL DI
# Extracting frames..../image_frames/frame73.1850.png
# fo o#
#
# i
# in
# EL SECRETO MEJOR GUARDADO. ss
#
# QUE SE SABE DEL DI
# Extracting frames..../image_frames/frame74.1875.png
# EL SECRETO MEJOR GUARDADO ro)
#
# QUE SE SABE DEL DI
# Extracting frames..../image_frames/frame75.1900.png
# | if ] ———————
#
# EL SECRETO MEJOR CHUN I>) \o10) i
#
# QUE SE SABE DEL DI RICIO MACRI
# Extracting frames..../image_frames/frame76.1925.png
# f if
# APERTURA DE SESIONES EN ELCONGRESO EL SECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DI D
#
# URICIO MACRI
# Extracting frames..../image_frames/frame77.1950.png
# i =
# f by
#
# ie
# APERTURA DE SESIONES EN EL CONGRESO ELSECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DISCU D URICIO MACRI
# Extracting frames..../image_frames/frame78.1975.png
# | ii
# POTS yy Re LUI UL)
#
# QUE SE SABE DEL DISCU D URICIO MACRI
#
#
#
#
#
#
# z)
#
# ~~
# Extracting frames..../image_frames/frame79.2000.png
# fie
#
# i fe Se
#
# it 4
# APERTURA DE SESIONES EN ELCONGRESO ELSECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DISCURSO D URICIO MACRI
# Extracting frames..../image_frames/frame80.2025.png
# /
#
# l a
# APERTURA DE SESIONES EN ELCONGRESO EL SECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DISCURSO D URICIO MACRI
#
#
#
#
# i Ms _—————m
# Extracting frames..../image_frames/frame81.2050.png
# f op
# | I -
# APERTURA DE SESIONES EN ELCONGRESO EL SECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
# Extracting frames..../image_frames/frame82.2075.png
# f hi
# if
#
# I
# APERTURA DE SESIONES EN ELCONGRESO ELSECRETO MEJOR GUARDADO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
# Extracting frames..../image_frames/frame83.2100.png
# Se 7 St | ities
# i WD | R eT] ( uJ —————
# uy i i |__. eae
# APERTURA DE SESIONES EN ELCONGRESO ELSECRETO MEJORGUARDADO | — #£
# Extracting frames..../image_frames/frame84.2125.png
#
# Extracting frames..../image_frames/frame85.2150.png
# il ha i
# i pp Cars i]
# ni
#
# : n
# APERTURA DE SESIONES EN EL CONGRESO EL SECRETO MEJOR GUARDADO
#
# art
# Extracting frames..../image_frames/frame86.2175.png
# o Z ;
# APERTURA DE SESIONES EN ELCONGRESO EL SECRETO MEJOR GUARDADO
#
# — elt
# Extracting frames..../image_frames/frame87.2200.png
# 1S ee 7
# ELSECRETO MEJORGUARDADO
# Extracting frames..../image_frames/frame88.2225.png
#
# Extracting frames..../image_frames/frame89.2250.png
# EL SECRETO MEJOR GUARDADO. APERTURA DE SESIONES EN EL CONGRESO
#
# aes
# Extracting frames..../image_frames/frame90.2275.png
# {/ yf
#
# lf i
# Kt oI
# EUSECRETO/MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
#
# a
# Extracting frames..../image_frames/frame91.2300.png
# ‘|;
# | {i a —=—
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# i QUE SE SABE DEL — us TTA) MACRI =
# Extracting frames..../image_frames/frame92.2325.png
# a:
# | uk “
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCU RICIO MACRI
#
# p
# Extracting frames..../image_frames/frame93.2350.png
# | -
# i ey
#
# i (Ay 4 |___ .inaommmgre
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
# cE
#
# QUE SE SABE DEL DI: RICIO MACRI
#
#
#
# es
# Extracting frames..../image_frames/frame94.2375.png
# Yih See
# / fy
#
# in ee
# Tm ANS) Ke) lo WA DAILY Wasi oly a Lee) [ols 0)
#
#
#
# QUE SE SABE DEL DISCU RICIO MACRI
# Extracting frames..../image_frames/frame95.2400.png
# fe =
# | a
# maa So Ley UL aa YW -silo SANT Mo) est axe)
#
# QUE SE SABE DEL ara ue Ted MACRI ‘=
#
# =
#
# |____ i sis
# Extracting frames..../image_frames/frame96.2425.png
# i hs a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL se DU erred Cc
# Extracting frames..../image_frames/frame97.2450.png
# Vi Vee a ae
# Wah al SS
#
# /
#
# EL SECRETO MEJOR ery APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL = ea Tg MACRI Cc
# Extracting frames..../image_frames/frame98.2475.png
# a Wisin ——
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL a ea Tg MACRI Cc
# i ' = ta
# Extracting frames..../image_frames/frame99.2500.png
# / WN tania
#
# EL SECRETO Aral ee APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
# Extracting frames..../image_frames/frame100.2525.png
# i Wa oo
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI Cc
#
# SS tn
# Extracting frames..../image_frames/frame101.2550.png
# if A INTERNET
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO.
#
# QUE SE SABE DEL DISCURSO
#
# i
#
# RICIO MACRI
# Extracting frames..../image_frames/frame102.2575.png
# vi A INTERNET ——————
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCUR
#
# i
#
# URICIO MACRI
# Extracting frames..../image_frames/frame103.2600.png
# a Oza
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCUR URICIO MACRI
# Extracting frames..../image_frames/frame104.2625.png
# ae A INTERNET
#
# i
# Li
# EL SECRETO MEJOR GUARDADO =APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURS
#
# i
#
# URICIO MACRI
# Extracting frames..../image_frames/frame105.2650.png
# ay: A INTERNE!
#
# i
# [i <
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
#
# QUE SE SABE DEL DISCURS URICIO MACRI
# Extracting frames..../image_frames/frame106.2675.png
# f Ye 7M tat dd
#
# /
#
# i et
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO i
#
# QUE SE SABE DEL DISCURS URICIO MACRI
#
#
#
# f? ee
# Extracting frames..../image_frames/frame107.2700.png
# if Iie VAN UL Ls
#
# / ft | ee
#
# EL SECRETO MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO n
#
# QUE SE SABE DEL DISCUR RICIO MACRI
# Extracting frames..../image_frames/frame108.2725.png
# / ts) Va UL SAD Le
#
# | lh 4 Same ee
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO - r
#
# QUE SE SABE DEL DISCUR RICIO MACRI
# Extracting frames..../image_frames/frame109.2750.png
# | My ALINTENINED
#
# ip —_—£_{_{_££
#
# s
# nl
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO i
#
# QUE SE SABE DEL DISCUR RICIO MACRI
# Extracting frames..../image_frames/frame110.2775.png
# I re Foe WL eli
#
# ey]
# Extracting frames..../image_frames/frame111.2800.png
# I
#
# {v Ca UU LS DOIN ded
# i 3
# n
#
# BI
#
# : ‘
# [a4 aod alo) ey loa UZ DE SESIONES EN EL CONGRESO
#
#
#
# —
# Extracting frames..../image_frames/frame112.2825.png
# i far CoS UUM SN
# a
# ELSECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUES
# Extracting frames..../image_frames/frame113.2850.png
# if [ir Co MUU Jit SOUS Sed
# s
#
# PW 4 aCe ale) Keyl aU we SESIONES EN EL CONGRESO
#
# QUE SE
# Extracting frames..../image_frames/frame114.2875.png
# Ie 7 Oe SA ke
#
# ce]
#
#
#
# H
# Ta) elo Fl TYPO MUP) e ls ee) elit 10) | —
#
# QUE SE SAB iW -t3 Y Cc
# Extracting frames..../image_frames/frame115.2900.png
# Von WUD US el
#
# A. i
# EUSECRETO MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO — oe
#
# | i
# i
# Extracting frames..../image_frames/frame116.2925.png
# / [Si PWN UA ———
# | i —
# s |_ += aseseamesiee
#
# Aal n 0
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO | —_—a
# Extracting frames..../image_frames/frame117.2950.png
# I ii AINTERINE! E
# | | | ——
#
# Eis H A a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO | r —
# Extracting frames..../image_frames/frame118.2975.png
# f hy 7A UP tat St
#
# if
# a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO D URICIO MACRI
# Extracting frames..../image_frames/frame119.3000.png
# f I AINTERINE! —
# im =| ——_——
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO D URICIO MACRI Cc
#
# — J Sn, i
# Extracting frames..../image_frames/frame120.3025.png
# fh Hd rN St =
#
# / Se
#
# | I 4| RE
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO D URICIO MACRI Ec
#
# = 7 Ss =
# Extracting frames..../image_frames/frame121.3050.png
# ‘a TWN
# | {! H|
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame122.3075.png
# oy) A INTERNE!
#
# i Mt
# EUSECRETO MEJOR|GUARDADO) APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS' fo} RICIO MACRI
# Extracting frames..../image_frames/frame123.3100.png
# /
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS' fo} RICIO MACRI
#
#
#
#
#
#
# a A INTERNET ———_
# Extracting frames..../image_frames/frame124.3125.png
# ft AINTERNET
#
# i i _———————
#
# { 4
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS' fo} RICIO MACRI
# Extracting frames..../image_frames/frame125.3150.png
# / i INE
# i fi
# it
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS' fo} RICIO MACRI
# Extracting frames..../image_frames/frame126.3175.png
# a. UN aaa
#
# ‘in
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS fe)
#
# i
#
# RICIO MACRI
# Extracting frames..../image_frames/frame127.3200.png
# a) AINTERNE!
# it =
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
#
# QUE SE SABE DEL DIS' fo} RICIO MACRI
# Extracting frames..../image_frames/frame128.3225.png
# a: A INTERNE!
#
# |
# I (h 2
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO i
#
# QUE SE SABE DEL DISCU 5 RICIO MACRI
# Extracting frames..../image_frames/frame129.3250.png
# / i AINTERNE!
#
# |
# (W
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO i
#
# QUE SE SABE DEL DISCU 5 RICIO MACRI
# Extracting frames..../image_frames/frame130.3275.png
# ary AINTERNE!
#
# /
# {' -
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO i
#
# QUE SE SABE DEL DISCURSO DE RICIO MACRI
# Extracting frames..../image_frames/frame131.3300.png
# , of A INTERNE!
#
# Ih
# [) -
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO r
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame132.3325.png
# a. 7) A INTERNE!
#
# \
# eee ee
# | 7 ee ee
#
# i iH) +a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame133.3350.png
# / Wt A INTERNE!
#
# —_— ee
# i “ i  —
#
# 1B! es
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO
#
# i
#
# URICIO MACRI
# Extracting frames..../image_frames/frame134.3375.png
# ( HH 7 NU
#
# lh
# | it =
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO -
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame135.3400.png
# i
#
# (B A
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
#
#
#
# iY TINS ls ———————
# Extracting frames..../image_frames/frame136.3425.png
# f HE Ta te
# | I s
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONESENELCONGRESO |
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame137.3450.png
# f ie TUS eo
#
# ll
# ie
#
# ! I
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES ENELCONGRESO >
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
#
# C
# Extracting frames..../image_frames/frame138.3475.png
# ‘|i 7AM ath
# i
# |
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame139.3500.png
# f lis AINTERINE! =,
# i Ip
#
# s
# , n
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO —
# Extracting frames..../image_frames/frame140.3525.png
# / ; AINIERINE! ae
# | | —————
#
# A nl o
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SA AAUR ' Cc
# Extracting frames..../image_frames/frame141.3550.png
# isi: eA Le
# i os ——
#
# »! n
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# meee ss
# Extracting frames..../image_frames/frame142.3575.png
# } ki Fon A ad a
# i ss
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN ELCONGRESO | y
#
# QUE SE:
# Extracting frames..../image_frames/frame143.3600.png
# ‘i [ oD AS ~
#
# s SSS
# Extracting frames..../image_frames/frame144.3625.png
# i hi oD AS LSE ~
#
# | i } Fa ——=—
#
# ‘
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
# Extracting frames..../image_frames/frame145.3650.png
# My Ze UA LE
# D se
#
# A
# 1 ot 514 fo) MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO
#
# oa Ps
# Extracting frames..../image_frames/frame146.3675.png
# POU at Sd
# Extracting frames..../image_frames/frame147.3700.png
# i ii 7 at LS a
# i by —_—_—_—_—_—_—_—=>=_
# ss) | A
#
# = + u
# fs CN FR). N UN N  Pme) els o —
# Extracting frames..../image_frames/frame148.3725.png
# f is AINTERINE!
#
# ip —— EE
#
# eI
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame149.3750.png
# ‘a |: TWN ath LU =
#
# lt 4 ee
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
# QUE SE SABE DEL DISCURSO URICIO MACRI
#
# ie
# Extracting frames..../image_frames/frame150.3775.png
# ee NU at LSU
#
# ie ea
#
# l }
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame151.3800.png
# rn) AINTERNE!
#
# i Pt
#
# iD ae
#
# | oI
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame152.3825.png
# fh AINTERNET
#
# i
# / Us <
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO URICIO MACRI
# Extracting frames..../image_frames/frame153.3850.png
# at: A INTERNET
#
# i
# | iB P|
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
# Extracting frames..../image_frames/frame154.3875.png
# nti A INTERNET —_
# {i ar,
#
# EL SECRETO Pale GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
# Extracting frames..../image_frames/frame155.3900.png
# i
# {i
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
#
#
#
# a A INTERNET —>__=
# Extracting frames..../image_frames/frame156.3925.png
# ih A INTERNET
#
#
#
# =
# | i ay
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
# Extracting frames..../image_frames/frame157.3950.png
# Ye wi = \
# at A INTERNE! =
#
# fk ——
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO RICIO MACRI
#
# ae iim.
# Extracting frames..../image_frames/frame158.3975.png
# ma! PWNS
#
# (i
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO r
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame159.4000.png
# at A INTERNE!
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO 7
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame160.4025.png
# ih Na ——_—
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# SS inp».
# Extracting frames..../image_frames/frame161.4050.png
# ae Wi, A INTERNE! ————————
# i fl a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO r
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI E
# = = iim
# Extracting frames..../image_frames/frame162.4075.png
# an TNA ll
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO r
#
# QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame163.4100.png
# If
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS'
#
#
#
# 1H A INTERNE! _————
# Extracting frames..../image_frames/frame164.4125.png
# an | A INTERNET
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO
#
# RICIO MACRI
# Extracting frames..../image_frames/frame165.4150.png
# | fe A INTERNET
#
# li
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DIS' SOD RICIO MACRI
# Extracting frames..../image_frames/frame166.4175.png
# fit A INTERNET SSS
# oo SS ee
#
# (
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL eine DE TSN AVN CL
# " a ee aio
# Extracting frames..../image_frames/frame167.4200.png
# an: A INTERNET ———s
#
# a 4)
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURSO D RICIO MACRI
# Extracting frames..../image_frames/frame168.4225.png
# a A INTERNET
#
# |
# ‘B a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURS RICIO MACRI
# Extracting frames..../image_frames/frame169.4250.png
# f oh WINS ai
#
# {i y|
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURS RICIO MACRI
# Extracting frames..../image_frames/frame170.4275.png
# f ok A INTERNET
#
# ! It ol
# EL SECRETO MEJOR GUARDADO + APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURS RICIO MACRI
# Extracting frames..../image_frames/frame171.4300.png
# a INAS a
#
# lh (a
#
# EUSECRETO MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURS RICIO MACRI
# Extracting frames..../image_frames/frame172.4325.png
# f A INTERNET
# i De os
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# QUE SE SABE DEL DISCURS RICIO MACRI
# Extracting frames..../image_frames/frame173.4350.png
# A INTERNET =
#
# | 5 |
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO. , _
#
# = QUE SE SAE
#
# —_
# Extracting frames..../image_frames/frame174.4375.png
# ' ! —_— y >
#
# = sd
#
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO | ccueul
#
# == QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame175.4400.png
# < ; = —— ee! K
# ~— EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# === QUE SE SABE DEL DISCURSO DE MAURICIO MACRI cE x
# Extracting frames..../image_frames/frame176.4425.png
# J
#
# a lee =
#
# EL SECRETO MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DEL DISCURSO DE MAURICIO MACRI =
# Extracting frames..../image_frames/frame177.4450.png
# & Bars a
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO I
#
# === QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame178.4475.png
# } = as
#
# |
#
# & N GRY ae
# EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# == QUESE SABE DE Wt RICIO MACRI E
# Extracting frames..../image_frames/frame179.4500.png
# ee. — bh
#
# i
#
# C Ss
# ~ EL SECRETO MEJOR GUARDADO APERTURA DE Sot EN EL CONGRESO
# Extracting frames..../image_frames/frame180.4525.png
# wi | a >
# ¢ Ea <
# i —
#
# ~_ELSECRETO MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO
#
# RON AITIU AM Nal] ol LaVelle NV Nel
# Extracting frames..../image_frames/frame181.4550.png
#
# Extracting frames..../image_frames/frame182.4575.png
#
# Extracting frames..../image_frames/frame183.4600.png
# © eartoncion — -
#
# —
#
# & % a
# ~ELSECRETO MEJOR GUARDADO) APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame184.4625.png
# ae
# = EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DELDIS
# Extracting frames..../image_frames/frame185.4650.png
# ; ———i
# — EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
# Extracting frames..../image_frames/frame186.4675.png
# ae
# = EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DELDIS MAURICIO MACRI
#
# = = = ——
# Extracting frames..../image_frames/frame187.4700.png
# BS 1 oP) KUL gs NASON AN Mody Cel 10)
#
# == QUE SE SABE DEL DIS AURICIO MACRI
# Extracting frames..../image_frames/frame188.4725.png
# @ h L © a
# — EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DEL DIS AURICIO MACRI
# Extracting frames..../image_frames/frame189.4750.png
# \\ a _
# = a
# < h ‘ a ee
# ~ ELSECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DEL DISCURSO DE MAURICIO MACRI
# Extracting frames..../image_frames/frame190.4775.png
# y a _
# < n t a
# ~ EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# SK TSAI ADM al) AURICIO MACRI
# Extracting frames..../image_frames/frame191.4800.png
# y) e >
# ~ EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# aeRO ASTI) 10-0 AURICIO MACRI
# Extracting frames..../image_frames/frame192.4825.png
# y : >.
# < ‘ & a
# ~ ELSECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO ra 4 F
#
# — QUE SE SABE DEL DIS AURICIO MACRI
# Extracting frames..../image_frames/frame193.4850.png
# J \ aay
# /
#
# i L a
# ~ EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# ee ' mK
# Extracting frames..../image_frames/frame194.4875.png
# 4 7
# (exan / & Se ee
# = ELSECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO ————
#
# See aT Ue) Ueto cn
# Extracting frames..../image_frames/frame195.4900.png
# y
#
# & N I . ee
# ~— ELSECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# = QUE SE SABE DELDI NYU roll Xela
# Extracting frames..../image_frames/frame196.4925.png
# = y ~ ————
# ~ EL SECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO
#
# Co. b>
#
# == QUE SE SABE DELD > DE MAURICIO MACRI
# Extracting frames..../image_frames/frame197.4950.png
# ») 1 o_
# ~— ELSECRETO MEJOR GUARDADO APERTURA DE SESIONES EN EL CONGRESO :
# Extracting frames..../image_frames/frame198.4975.png
# 4 VA
# & N / a
# —_ELSECRETO MEJOR GUARDADO  APERTURA DE SESIONES EN EL CONGRESO
#
# == QUE SE SABE DELDI , AURICI
# Extracting frames..../image_frames/frame199.5000.png
# & ae
# EL SECRETO MEJOR GUARDADO 3
# Cc a
# Extracting frames..../image_frames/frame200.5025.png
#
# Extracting frames..../image_frames/frame201.5050.png
